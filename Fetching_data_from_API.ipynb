# %% [markdown]
# <a href="https://colab.research.google.com/github/RazyAnas/MachineLearning/blob/main/Fetching_data_from_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
# df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dfs = []

for i in range(1, 429):
    response = requests.get(
        f"https://api.themoviedb.org/3/movie/top_rated"
        f"?api_key=8265bd1679663a7ea12ac168da84d2e8"
        f"&language=en-US&page={i}"
    )

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date',
         'popularity', 'vote_average', 'vote_count']
    ]

    dfs.append(temp_df)


df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#            id                        title  \
# 0     1007757                      Swapped
# 1         278     The Shawshank Redemption
# 2         238                The Godfather
# 3         240        The Godfather Part II
# 4         424             Schindler's List
# ...       ...                          ...
# 8555   864873                     Hypnotic
# 8556    70821                   Cyberbully
# 8557    44977                      Dhoom 3
# 8558    13490  Welcome Home Roscoe Jenkins
# 8559   483202                          Eli
#
#                                                overview release_date  \
# 0     A small woodland creature and a majestic bird,...   2026-05-01
# 1     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.to_csv('movies.csv')

# %%
# https://holidayapi.com/v1/holidays?key=f947ba25-bf3b-4794-b561-6e02012506e9&country=US&year=2025&pretty

# %%
dfs = []

for i in range(1, 429):
    response = requests.get(
        f"https://holidayapi.com/v1/holidays"
        f"?key=f947ba25-bf3b-4794-b561-6e02012506e9"
        f"&country=IN&year=2025"
    )

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date',
         'popularity', 'vote_average', 'vote_count']
    ]

    dfs.append(temp_df)


df = pd.concat(dfs, ignore_index=True)

# %%
response = requests.get('https://0fbf-117-96-147-218.ngrok-free.app/holidays.json', chunk=500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4281/624757682.py in <cell line: 0>()
# ----> 1 response = requests.get('https://0fbf-117-96-147-218.ngrok-free.app/holidays.json', chunk=500)
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# TypeError: Session.request() got an unexpected keyword argument 'chunk'
