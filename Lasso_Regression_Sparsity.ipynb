# %% [markdown]
# <a href="https://colab.research.google.com/github/RazyAnas/MachineLearning/blob/main/Lasso_Regression_Sparsity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Understanding Sparsity
# > Some values becomes zero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Case - 1 (m > 0) -> |m| = m

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### For all three cases - coefficient

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Case - 1 (m > 0) -> |m| = m

# %% [markdown]
# > zero tk kaise pahucha and uske baad case changes and we get worse value for m thats why lasso stops at zero keep on zero value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Case - 2 (m < 0)

# %% [markdown]
# > lambda always > 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Why no sparsity in ridge regression

# %% [markdown]
# ![image.png](data:image/png;base64,...)
