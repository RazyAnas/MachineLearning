# %% [markdown]
# <a href="https://colab.research.google.com/github/RazyAnas/MachineLearning/blob/main/100Days_AIML_Tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What are Tensors

# %% [markdown]
# ## 0D Tensor - Scalars
#
# No Dimensions - store single number [0]

# %% [markdown]
# import numpy as np

# %%
import numpy as np

# %%
a = np.array(4)
a
# Out:
# array(4)

# %% [markdown]
# ## 1D - Tensor
#
# 1D Tensor, array, Vector
# nDim = 1
#
# Axis = How many dimensions = 1D = 1 Axis = Rank 1
# Dimension of vector = 4D for 1D Tensor i.e [1,2,3,4]

# %%
oneD = np.array([2,10,18,19])
oneD
oneD.ndim
# Out:
# 1

# %% [markdown]
# ## 2D Tensor/Matrices
