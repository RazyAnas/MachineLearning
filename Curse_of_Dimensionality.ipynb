# %% [markdown]
# <a href="https://colab.research.google.com/github/RazyAnas/MachineLearning/blob/main/Curse_of_Dimensionality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curse of Dimensionality

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## What is Curse if Dimensionality
# - Features - dimensionals
# - Optiomal number of features fn < fm max features
#
# 28*28 pixels in MNIST dataset, what if we use optimal number of pixels to cover the text and remove the other pixels which isnt helping in classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem
# - Computation
# - Performance decrease

# %% [markdown]
# ## Solution is Dimensionality reduction
# - Feature Selection
#     - Forward selection
#     - Backward elemination
# - Feature extration
#     - PCA
#     - LDA
#     - TSNE

# %% [markdown]
# In summary Higher Dimensional Data is dangerous for the model
