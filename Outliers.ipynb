# %% [markdown]
# <a href="https://colab.research.google.com/github/RazyAnas/MachineLearning/blob/main/Outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What are outliers
# it pulls the probabilty nearby itself which is a problem
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Effect of Outliers on ML algorithms
# Linear
#
# Logistic
#
# Deeplearning
#
# Adaboost
#
#
# Because of **weights based algorithm**

# %% [markdown]
# # How to treat outliers
# 1. Trimming : Completely removed
#     - Thin data disadvantage
#     - Fast
# 2. Capping
#     - 1 and 90
# 3. Missing Value and Discretization

# %% [markdown]
# # How to detect Outliers

# %% [markdown]
# 1. Normal Distribution
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Skewed Distribution
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Percentile based approach
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # What we will use?
#
# 1. Z score treatment
# 2. IQR based fitting
# 3. Percentile
# 4. Winsorization
